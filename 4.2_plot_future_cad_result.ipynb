# %% [markdown]
# - rpy2

# %% [markdown]
# ## 画图

# %%
import pandas as pd

future_cad = pd.read_pickle("4.2_plot_future_cad.pkl")
incident_cad = pd.read_pickle("4.2_plot_incident_cad.pkl")

# %%
sns.barplot
# Out:
# task                                    10_years_cad                      \
# metric                                           ACC   ACC_LCI   ACC_UCI
# combination
# AS                                          0.608580  0.597849  0.618583
# COX                                         0.696071  0.686427  0.706197
# COX + RF                                    0.734635  0.724509  0.743679
# COX + RF + PRS                              0.635695  0.625569  0.645469
# COX(P_cutoff)                               0.743312  0.733909  0.752594
# COX(P_cutoff) + RF                          0.655339  0.645577  0.665582
# COX(P_cutoff) + RF + PRS                    0.705471  0.695824  0.715477
# LR                                          0.701494  0.691609  0.710894
# LR + RF                                     0.698843  0.689196  0.709090
# LR + RF +PRS                                0.641118  0.629670  0.651362
# LR(P_cutoff)                                0.602796  0.591829  0.614003
# ...
