# %%
library("survival")

# %%
# Create some sample data
x <- c(1, 2, 3, 4, 5)
y <- c(10, 15, 12, 18, 20)

# Plot the line chart
plot(x, y, type = "l", xlab = "X", ylab = "Y", main = "Line Chart")
# Out:
# Plot with title “Line Chart”
